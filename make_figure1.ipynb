# %% [markdown]
# # Figure Name
# Here we describe the figure created in this notebook. In this template, we will create a simple plot of example data.

# %% [markdown]
# First, we import our loader module.

# %%
from load_data import load_example

# %% [markdown]
# Next, load the data.

# %%
data = load_example()

# %% [markdown]
# Then, proceed with your analysis. Here, we will simply plot the data.

# %%
import matplotlib.pyplot as plt
for i in data:
    plt.scatter(data.index, data[i], label=i)
plt.title("Example Plot")
plt.ylabel("Value")
plt.legend(loc='lower right')
plt.show()
